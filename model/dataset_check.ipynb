# %%
import pandas as pd

# %%
csv_path = "dataset\exercise_detection\exercise_angles.csv"
df = pd.read_csv(csv_path)

# %%
print("=== Data Preview ===")
print(df.head(10))

print("\n=== Column Data Types ===")
print(df.dtypes)

non_numeric = df.select_dtypes(include=['object']).columns.tolist()
for col in non_numeric:
    print(f"\n=== Unique values in '{col}' ===")
    print(df[col].value_counts())

print("\n=== Numeric Feature Summary ===")
print(df.describe().T)
# Out:
# === Data Preview ===
#    Side  Shoulder_Angle  Elbow_Angle   Hip_Angle  Knee_Angle  Ankle_Angle  \
# 0  left       10.639208   174.466813  174.785143  179.848140   179.419276
# 1  left       10.590342   174.428706  174.765042  179.775215   179.386147
# 2  left       10.546746   174.489431  174.785790  179.660017   179.333710
# 3  left       10.487682   174.614913  174.759542  179.614223   179.313926
# 4  left       10.412107   174.758503  174.737721  179.570564   179.298805
# 5  left       10.333750   174.896478  174.717610  179.537286   179.290593
# 6  left       10.264989   175.019119  174.688875  179.497781   179.278232
# 7  left       10.184175   175.145197  174.676467  179.467305   179.278924
# 8  left       10.123361   175.358891  174.640657  179.445388   179.274274
# 9  left        9.953478   175.735486  174.708924  179.366058   179.276900
#
#    Shoulder_Ground_Angle  Elbow_Ground_Angle  Hip_Ground_Angle  \
# 0                   90.0                90.0              90.0
# 1                   90.0                90.0              90.0
# 2                   90.0                90.0              90.0
# 3                   90.0                90.0              90.0
# 4                   90.0                90.0              90.0
# 5                   90.0                90.0              90.0
# 6                   90.0                90.0              90.0
# 7                   90.0                90.0              90.0
# 8                   90.0                90.0              90.0
# 9                   90.0                90.0              90.0
#
#    Knee_Ground_Angle  Ankle_Ground_Angle          Label
# 0               90.0                90.0  Jumping Jacks
# 1               90.0                90.0  Jumping Jacks
# 2               90.0                90.0  Jumping Jacks
# 3               90.0                90.0  Jumping Jacks
# 4               90.0                90.0  Jumping Jacks
# 5               90.0                90.0  Jumping Jacks
# 6               90.0                90.0  Jumping Jacks
# 7               90.0                90.0  Jumping Jacks
# 8               90.0                90.0  Jumping Jacks
# 9               90.0                90.0  Jumping Jacks
#
# === Column Data Types ===
# Side                      object
# Shoulder_Angle           float64
# Elbow_Angle              float64
# Hip_Angle                float64
# Knee_Angle               float64
# Ankle_Angle              float64
# Shoulder_Ground_Angle    float64
# Elbow_Ground_Angle       float64
# Hip_Ground_Angle         float64
# Knee_Ground_Angle        float64
# Ankle_Ground_Angle       float64
# Label                     object
# dtype: object
#
# === Unique values in 'Side' ===
# Side
# left    31033
# Name: count, dtype: int64
#
# === Unique values in 'Label' ===
# Label
# Push Ups          9764
# Pull ups          6659
# Jumping Jacks     5209
# Squats            4997
# Russian twists    4404
# Name: count, dtype: int64
#
# === Numeric Feature Summary ===
#                          count        mean        std        min         25%  \
# Shoulder_Angle         31033.0   66.522206  60.226756   0.002748   17.852184
# Elbow_Angle            31033.0  114.303010  57.906279   0.000974   58.900491
# Hip_Angle              31033.0  137.466151  57.048278   0.006850  111.556724
# Knee_Angle             31033.0  143.273623  48.041715   0.116036  123.646144
# Ankle_Angle            31033.0  135.211957  53.304068   0.031297  106.740814
# Shoulder_Ground_Angle  31033.0   88.816743  14.546233 -90.000000   90.000000
# Elbow_Ground_Angle     31033.0   88.926949  13.856550 -90.000000   90.000000
# Hip_Ground_Angle       31033.0   79.408694  42.359381 -90.000000   90.000000
# Knee_Ground_Angle      31033.0   75.795121  48.530150 -90.000000   90.000000
# Ankle_Ground_Angle     31033.0   68.985596  57.802208 -90.000000   90.000000
#
#                               50%         75%         max
# Shoulder_Angle          40.585632  121.209005  179.991577
# Elbow_Angle            132.999090  168.769517  179.998861
# Hip_Angle              168.374922  175.656498  179.999848
# Knee_Angle             168.227063  177.225089  179.999277
# Ankle_Angle            162.926184  175.735039  179.999942
# Shoulder_Ground_Angle   90.000000   90.000000   90.000000
# Elbow_Ground_Angle      90.000000   90.000000   90.000000
# Hip_Ground_Angle        90.000000   90.000000   90.000000
# Knee_Ground_Angle       90.000000   90.000000   90.000000
# Ankle_Ground_Angle      90.000000   90.000000   90.000000
